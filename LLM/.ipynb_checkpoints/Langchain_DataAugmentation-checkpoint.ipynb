# %%
import pandas as pd

# Sample dataset
data = {
    'product_id': [1, 2, 3],
    'product_name': ['Laptop', 'Smartphone', 'Headphones'],
    'description': [
        'A high-performance laptop with a sleek design.',
        'The latest smartphone with cutting-edge features.',
        'Comfortable headphones with noise-cancellation.'
    ],
    'price': [999.99, 799.99, 199.99],
    'category': ['Electronics', 'Electronics', 'Accessories']
}

df = pd.DataFrame(data)
print(df)
# Out:
#    product_id product_name                                        description  \
# 0           1       Laptop     A high-performance laptop with a sleek design.
# 1           2   Smartphone  The latest smartphone with cutting-edge features.
# 2           3   Headphones    Comfortable headphones with noise-cancellation.
#
#     price     category
# 0  999.99  Electronics
# 1  799.99  Electronics
# 2  199.99  Accessories

# %%
import os
from langchain.llms import OpenAI
from langchain.prompts import PromptTemplate

# Set your OpenAI API key
os.environ['OPENAI_API_KEY'] = 'llm = OpenAI(model='gpt-4', temperature=0.7)
# Out:
# C:\Users\kkksk\AppData\Local\Temp\ipykernel_18308\3955370653.py:7: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAI``.
#   llm = OpenAI(model='gpt-4', temperature=0.7)

# %%
def generate_synthetic_row(row):
    prompt = f"""
    Generate a new product entry similar to the following:
    
    Product Name: {row['product_name']}
    Description: {row['description']}
    Category: {row['category']}
    Price: {row['price']}
    
    Output a new product entry with the same format:
    """
    
    synthetic_text = llm(prompt)
    
    # Parse the generated text to extract fields (assuming the format is consistent)
    lines = synthetic_text.split('\n')
    synthetic_row = {}
    for line in lines:
        if ':' in line:
            key, value = line.split(':', 1)
            synthetic_row[key.strip()] = value.strip()
    
    return synthetic_row

# %%
synthetic_data = []

# Generate 3 synthetic rows
for i in range(3):
    sample_row = df.sample(1).iloc[0]  # Pick a random row to use as a template
    new_row = generate_synthetic_row(sample_row)
    synthetic_data.append(new_row)

# Convert the synthetic data to a DataFrame
synthetic_df = pd.DataFrame(synthetic_data)
print("\nSynthetic DataFrame:")
print(synthetic_df)
# Out:
# C:\Users\kkksk\AppData\Local\Temp\ipykernel_18308\771358853.py:13: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   synthetic_text = llm(prompt)
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18308\2708329730.py in <module>
#       4 for i in range(3):
#       5     sample_row = df.sample(1).iloc[0]  # Pick a random row to use as a template
# ----> 6     new_row = generate_synthetic_row(sample_row)
#       7     synthetic_data.append(new_row)
#       8
#
# ~\AppData\Local\Temp\ipykernel_18308\771358853.py in generate_synthetic_row(row)
#      11     """
#      12
# ---> 13     synthetic_text = llm(prompt)
#      14
#      15     # Parse the generated text to extract fields (assuming the format is consistent)
#
# C:\Anaconda\lib\site-packages\langchain_core\_api\deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     180                 warned = True
#     181                 emit_warning()
# --> 182             return wrapped(*args, **kwargs)
#     183
#     184         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# C:\Anaconda\lib\site-packages\langchain_core\language_models\llms.py in __call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1275             raise ValueError(msg)
#    1276         return (
# -> 1277             self.generate(
#    1278                 [prompt],
#    1279                 stop=stop,
#
# C:\Anaconda\lib\site-packages\langchain_core\language_models\llms.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     948                 )
#     949             ]
# --> 950             output = self._generate_helper(
#     951                 prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     952             )
#
# C:\Anaconda\lib\site-packages\langchain_core\language_models\llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     790             for run_manager in run_managers:
#     791                 run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 792             raise e
#     793         flattened_outputs = output.flatten()
#     794         for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# C:\Anaconda\lib\site-packages\langchain_core\language_models\llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     777         try:
#     778             output = (
# --> 779                 self._generate(
#     780                     prompts,
#     781                     stop=stop,
#
# C:\Anaconda\lib\site-packages\langchain_community\llms\openai.py in _generate(self, prompts, stop, run_manager, **kwargs)
#     461                 )
#     462             else:
# --> 463                 response = completion_with_retry(
#     464                     self, prompt=_prompts, run_manager=run_manager, **params
#     465                 )
#
# C:\Anaconda\lib\site-packages\langchain_community\llms\openai.py in completion_with_retry(llm, run_manager, **kwargs)
#     119     """Use tenacity to retry the completion call."""
#     120     if is_openai_v1():
# --> 121         return llm.client.create(**kwargs)
#     122
#     123     retry_decorator = _create_retry_decorator(llm, run_manager=run_manager)
#
# C:\Anaconda\lib\site-packages\openai\_utils\_utils.py in wrapper(*args, **kwargs)
#     272                         msg = f"Missing required argument: {quote(missing[0])}"
#     273                 raise TypeError(msg)
# --> 274             return func(*args, **kwargs)
#     275
#     276         return wrapper  # type: ignore
#
# C:\Anaconda\lib\site-packages\openai\resources\completions.py in create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, stream_options, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     526         timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     527     ) -> Completion | Stream[Completion]:
# --> 528         return self._post(
#     529             "/completions",
#     530             body=maybe_transform(
#
# C:\Anaconda\lib\site-packages\openai\_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1258             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1259         )
# -> 1260         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1261
#    1262     def patch(
#
# C:\Anaconda\lib\site-packages\openai\_base_client.py in request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     935         stream_cls: type[_StreamT] | None = None,
#     936     ) -> ResponseT | _StreamT:
# --> 937         return self._request(
#     938             cast_to=cast_to,
#     939             options=options,
#
# C:\Anaconda\lib\site-packages\openai\_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1039
#    1040             log.debug("Re-raising status error")
# -> 1041             raise self._make_status_error_from_response(err.response) from None
#    1042
#    1043         return self._process_response(
#
# NotFoundError: Error code: 404 - {'error': {'message': 'This is a chat model and not supported in the v1/completions endpoint. Did you mean to use v1/chat/completions?', 'type': 'invalid_request_error', 'param': 'model', 'code': None}}

# %%
from langchain_core.prompts import FewShotPromptTemplate, PromptTemplate
from langchain_core.pydantic_v1 import BaseModel
from langchain_experimental.tabular_synthetic_data.openai import (
    OPENAI_TEMPLATE,
    create_openai_data_generator,
)
from langchain_experimental.tabular_synthetic_data.prompts import (
    SYNTHETIC_FEW_SHOT_PREFIX,
    SYNTHETIC_FEW_SHOT_SUFFIX,
)
from langchain_openai import ChatOpenAI
# Out:
# C:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3457: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18308\3147727701.py in <module>
#       1 from langchain_core.prompts import FewShotPromptTemplate, PromptTemplate
#       2 from langchain_core.pydantic_v1 import BaseModel
# ----> 3 from langchain_experimental.tabular_synthetic_data.openai import (
#       4     OPENAI_TEMPLATE,
#       5     create_openai_data_generator,
#
# ModuleNotFoundError: No module named 'langchain_experimental'

# %%
pip install --upgrade --quiet  langchain langchain_experimental langchain-openai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_core.prompts import FewShotPromptTemplate, PromptTemplate
from langchain_core.pydantic_v1 import BaseModel
from langchain_experimental.tabular_synthetic_data.openai import (
    OPENAI_TEMPLATE,
    create_openai_data_generator,
)
from langchain_experimental.tabular_synthetic_data.prompts import (
    SYNTHETIC_FEW_SHOT_PREFIX,
    SYNTHETIC_FEW_SHOT_SUFFIX,
)
from langchain_openai import ChatOpenAI

# %%
class TransactionRecord(BaseModel):
    transaction_id: str
    customer_id: str
    transaction_amount: float
    transaction_date: str
    payment_method: str
    product_category: str
    quantity: int
    customer_age: int
    customer_location: str
    device_used: str
    ip_address: str
    shipping_address: str
    billing_address: str
    is_fraudulent: int
    account_age_days: int
    transaction_hour: int

# %%
examples = [
    { "example": """transaction_id: 15d2e414-8735-46fc-9e02-80b472b2580f, customer_id: d1b87f62-51b2-493b-ad6a-77e0fe13e785, transaction_amount: 58.09, transaction_date: 2024-02-20 05:58:41, payment_method: bank transfer, product_category: home & garden, quantity: 4, customer_age: 37, customer_location: Christopherland, device_used: desktop, ip_address: 211.189.218.190, shipping_address: 471 Mary Courts Apt. 872\nMaryhaven, KS 16126, billing_address: 471 Mary Courts Apt. 872\nMaryhaven, KS 16126, is_fraudulent: 1, account_age_days: 30, transaction_hour: 5"""},
    {"example": """transaction_id: aa81b9ff-034d-4d8e-bec6-ed29b8ae5d54, customer_id: 37de64d5-e901-4a56-9ea0-af0c24c069cf, transaction_amount: 389.96, transaction_date: 2024-02-25 08:09:45, payment_method: debit card, product_category: electronics, quantity: 32, customer_age: 40, customer_location: East Timothy, device_used: desktop, ip_address: 208.106.249.121, shipping_address: 634 May Keys\nPort Cherylview, NV 75063, billing_address: 634 May Keys\nPort Cherylview, NV 75063, is_fraudulent: 0, account_age_days: 72, transaction_hour: 8"""},
    {"example": """transaction_id: 7ac1febd-3e94-457e-bfe4-acf081dc8da0, customer_id: 104.07, transaction_amount: 07/01/2024 15:41, transaction_date: 134.19, payment_method: PayPal, product_category: electronics, quantity: 1, customer_age: 43, customer_location: Paynefurt, device_used: tablet, ip_address: 195.31.145.184, shipping_address: Unit 5864 Box 9572\nDPO AE 69746, billing_address: Unit 5864 Box 9572\nDPO AE 69746, is_fraudulent: 1, account_age_days: 15, transaction_hour: 15"""},
]

# %%
[
    {
        "Transaction ID": "15d2e414-8735-46fc-9e02-80b472b2580f",
        "Customer ID": "d1b87f62-51b2-493b-ad6a-77e0fe13e785",
        "Transaction Amount": 58.09,
        "Transaction Date": "2024-02-20 05:58:41",
        "Payment Method": "bank transfer",
        "Product Category": "electronics",
        "Quantity": 1,
        "Customer Age": 17,
        "Customer Location": "Amandaborough",
        "Device Used": "tablet",
        "IP Address": "212.195.49.198",
        "Shipping Address": "Unit 8934 Box 0058\nDPO AA 05437",
        "Billing Address": "Unit 8934 Box 0058\nDPO AA 05437",
        "Is Fraudulent": 0,
        "Account Age Days": 30,
        "Transaction Hour": 5
    },
    {
        "Transaction ID": "0bfee1a0-6d5e-40da-a446-d04e73b1b177",
        "Customer ID": "37de64d5-e901-4a56-9ea0-af0c24c069cf",
        "Transaction Amount": 389.96,
        "Transaction Date": "2024-02-25 08:09:45",
        "Payment Method": "debit card",
        "Product Category": "electronics",
        "Quantity": 2,
        "Customer Age": 40,
        "Customer Location": "East Timothy",
        "Device Used": "desktop",
        "IP Address": "208.106.249.121",
        "Shipping Address": "634 May Keys\nPort Cherylview, NV 75063",
        "Billing Address": "634 May Keys\nPort Cherylview, NV 75063",
        "Is Fraudulent": 0,
        "Account Age Days": 72,
        "Transaction Hour": 8
    },
    {
        "Transaction ID": "e588eef4-b754-468e-9d90-d0e0abfc1af0",
        "Customer ID": "1bac88d6-4b22-409a-a06b-425119c57225",
        "Transaction Amount": 134.19,
        "Transaction Date": "2024-03-18 03:42:55",
        "Payment Method": "PayPal",
        "Product Category": "home & garden",
        "Quantity": 2,
        "Customer Age": 22,
        "Customer Location": "Davismouth",
        "Device Used": "tablet",
        "IP Address": "76.63.88.212",
        "Shipping Address": "16282 Dana Falls Suite 790\nRothhaven, IL 15564",
        "Billing Address": "16282 Dana Falls Suite 790\nRothhaven, IL 15564",
        "Is Fraudulent": 0,
        "Account Age Days": 63,
        "Transaction Hour": 3
    }
]

# %%
OPENAI_TEMPLATE = PromptTemplate(input_variables=["example"], template="{example}")

prompt_template = FewShotPromptTemplate(
    prefix=SYNTHETIC_FEW_SHOT_PREFIX,
    examples=examples,
    suffix=SYNTHETIC_FEW_SHOT_SUFFIX,
    input_variables=["subject", "extra"],
    example_prompt=OPENAI_TEMPLATE,
)

# %%
transaction_record_schema = TransactionRecord.schema()

# %%
synthetic_data_generator = create_openai_data_generator(
    output_schema=transaction_record_schema,
    llm=ChatOpenAI(
        temperature=1,
          api_key='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'
    ),  
    prompt=prompt_template,
)

# %%
synthetic_results = synthetic_data_generator.generate(
    subject="TransactionRecord",
    extra="Include details typical of fraudulent e-commerce transactions, such as unusually large transaction amounts or suspicious IP addresses",
    runs=15,
)

# %%
len(synthetic_results)
# Out:
# 15

# %%
synthetic_df = pd.DataFrame(synthetic_results)

# %%
synthetic_df
# Out:
#                                transaction_id customer_id  transaction_amount  \
# 0   73aabbcd-abc1-23de-4567-90f1-23456789abcd         283             1050.76
# 1        2cd67f89-4a13-4f7d-b0fd-6f8cf387cc31      367.89              512.36
# 2        98ab456d-7890-12cd-34ef-56ab789cde01      205.67              750.98
# 3        8e9f76ab-12cd-34ef-56ab-789cde01fga2         900             1200.50
# 4        abfde987-6543-2109-8765-4321dcbafe98      675.43              890.20
# 5                                      abc123      555.67              650.75
# 6                                      abc123      555.67              650.75
# 7                                  abcdef1234      789.01             1200.50
# 8                                      xyz987      123.45              800.99
# 9                                      syn123      111.11              900.00
# 10                                     syn456      222.22             1500.70
# 11                                     syn789      333.33             2000.55
# 12                                     syn987      444.44             3000.00
# 13                                     syn123      111.11             2500.99
# 14                                     syn456      222.22             1800.75
#
#     transaction_date  payment_method   product_category  quantity  \
# 0   2024-09-15 12:30     credit card        electronics         2
# 1   2025-03-18 09:45     credit card        electronics         3
# 2   2023-11-20 14:25     credit card           clothing         1
# 3   2024-08-10 15:20     credit card        electronics         2
# 4   2024-05-15 17:30          paypal            jewelry         1
# 5   2025-03-12 10:45     credit card        electronics         1
# 6   2025-03-12 10:45     credit card        electronics         1
# 7   2026-08-20 22:15         bitcoin     luxury watches         1
# 8   2027-05-15 16:30          paypal            jewelry         2
# 9   2028-10-25 08:00     credit card        electronics         1
# 10  2029-03-12 10:45  cryptocurrency    luxury handbags         1
# 11  2030-07-20 14:15         bitcoin     luxury watches         1
# 12  2031-05-15 16:30          paypal   high-end jewelry         1
# 13  2032-09-18 13:50     credit card        electronics         1
# 14  2033-11-12 10:45  cryptocurrency  designer handbags         1
#
#     customer_age   customer_location   device_used         ip_address  \
# 0             41        Parkway East        mobile        192.168.1.1
# 1             28      East Riverdale        mobile     203.187.154.92
# 2             35            Westwood  123.45.67.89    4567 Oak Street
# 3             43          South Port       desktop      210.176.45.78
# 4             30    Downtown Heights        mobile       189.76.54.32
# 5             28            Downtown  128.56.34.78  7890 Maple Street
# 6             28            Downtown  128.56.34.78  7890 Maple Street
# 7             35        Uptown Plaza       desktop       123.45.67.89
# 8             30            Suburbia   45.67.89.12    5678 Elm Street
# 9             25         City Center   192.168.1.1   1234 Pine Street
# 10            28       Downtown Mall        mobile       987.65.43.21
# 11            35  Financial District    172.16.0.1    3456 Oak Avenue
# 12            30       Luxury Avenue   10.20.30.40    5678 Elm Street
# 13            25   Suspicious Street   192.168.1.1       123.45.67.89
# 14            40        Shady Street   99.88.77.66    9876 Maple Road
#
#        shipping_address      billing_address  is_fraudulent  account_age_days  \
# 0       8253 Elm Street      8253 Elm Street              1                60
# 1     4182 Maple Street    4182 Maple Street              1                45
# 2       4567 Oak Street      4567 Oak Street              1                30
# 3      6321 Pine Street     6321 Pine Street              1                50
# 4       9876 Elm Street      9876 Elm Street              1                40
# 5     7890 Maple Street    7890 Maple Street              1                25
# 6     7890 Maple Street    7890 Maple Street              1                25
# 7       1234 Oak Avenue      1234 Oak Avenue              1                60
# 8       5678 Elm Street      5678 Elm Street              1                40
# 9      1234 Pine Street     1234 Pine Street              1                30
# 10     876 Maple Street     876 Maple Street              1                20
# 11      3456 Oak Avenue      3456 Oak Avenue              1                15
# 12      5678 Elm Street      5678 Elm Street              1                10
# 13  123 Suspicious Lane  123 Suspicious Lane              1                 5
# 14      9876 Maple Road      9876 Maple Road              1                 8
#
#     transaction_hour
# 0                 12
# 1                  9
# 2                 14
# 3                 15
# 4                 17
# 5                 10
# 6                 10
# 7                 22
# 8                 16
# 9                  8
# 10                10
# 11                14
# 12                16
# 13                13
# 14                10
